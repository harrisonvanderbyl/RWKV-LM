# %% [markdown]
# # RWKV Token Shift Experiment A
# This model is a custom model containing
# - 12 layers
# - 2560 embedding size
#
# See `./notes.md` for how the init model was initilaized.
#
# **Note:** This project assumes you have the rwkv-infctx conda env setup
#
# ---
#
# ```bash
# # ninja-build is required for the new trainer
# sudo apt-get install ninja-build
#
# # Update conda & its package listings
# conda update conda
#
# # Virtual env, with python 3.10
# # python 3.11 have issues with torch.compile / h100s
# # and if you want to use 3.11, you will need to do a nightly build install
# conda create -n rwkv-infctx python=3.11 pip
# conda activate rwkv-infctx
#
# # Install pytorch (>=2.0.1)
# conda install -y pytorch==2.0.1 torchvision torchaudio pytorch-cuda=11.8 -c pytorch -c nvidia
#
# # Verify your pytorch version
# python -c "import torch; print(torch.__version__)"
#
# # We use python -m pip, instead of pip directly, as it resolve issues with venv not loading the right pip
# python -m pip install datasets transformers
# python -m pip install lightning==2.0.4 deepspeed==0.9.5
# python -m pip install ninja numexpr jsonargparse 'jsonargparse[signatures]'
# python -m pip install lm-dataformat ftfy sentencepiece tokenizers wandb
# ```
# ---

# %% [markdown]
# # Basic Setup

# %%
# First lets setup the various directories, and get the blank init model, these init model was generated
# using the original RWKV-LM repo (as at this point of writing, this repo cannot init a model)
# As such I have preinitialized these blank models and uploaded them to HF for convinence
# !mkdir -p ../../../model/
# !mkdir -p ../../../datapath/
# !mkdir -p ../../../checkpoint/
# !rm -rf ../../../model/L12-D2560-init.pth
# !cd ../../../model/ && wget https://huggingface.co/picocreator/memory-size-experiment-for-rwkv/resolve/main/L12-D2560-init.pth
# !ls -alh ../../../model/L12-D2560-init.pth
# Out:
# --2023-07-15 01:12:48--  https://huggingface.co/picocreator/memory-size-experiment-for-rwkv/resolve/main/L12-D2560-init.pth
# Resolving huggingface.co (huggingface.co)... 13.224.249.10, 13.224.249.43, 13.224.249.44, ...
# Connecting to huggingface.co (huggingface.co)|13.224.249.10|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/cb/ef/cbef09abb2634a3375b28868bffa285226dfeabedec89b28c2fb302221164d66/490b49cdae99030f402fa01a60817bb53c67b6164aa3858742ea6b1560b2c4ed?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27L12-D2560-init.pth%3B+filename%3D%22L12-D2560-init.pth%22%3B&Expires=1689613968&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=Zmghrl%7EqBOcsLy6Yb%7ESOJWV5Cy85oQ5-psOE39OoJ1%7Ef6Z2GrQanRuAywj7l4fr9-OJiBjZxr%7E%7EEE9VDANl%7EOtmYoqZKn6hmdimCNi6HFO6Gh0Nr5IA2dMbKv61rfScjK1RDSEy6g-HA7aGfINGwGQqEuAEiLKQYEfUEDLt9nIgFKXBbxYi9ZUcrf6N0lUov%7E-qixQxD0qGrzZX4cmCRs6rIB0P5oRWT-Kejo2qAckVr%7EK3YaB5m3n7z6ZwaXX6JEZik-0vGfmQiipPZPAtqT9NOT-RpjOFi0VOGn5xf3uZkSLGcL2rGGxbHldkdndK3lyIpB-PKo0ZrPWs4l5dnmQ__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2023-07-15 01:12:48--  https://cdn-lfs.huggingface.co/repos/cb/ef/cbef09abb2634a3375b28868bffa285226dfeabedec89b28c2fb302221164d66/490b49cdae99030f402fa01a60817bb53c67b6164aa3858742ea6b1560b2c4ed?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27L12-D2560-init.pth%3B+filename%3D%22L12-D2560-init.pth%22%3B&Expires=1689613968&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=Zmghrl%7EqBOcsLy6Yb%7ESOJWV5Cy85oQ5-psOE39OoJ1%7Ef6Z2GrQanRuAywj7l4fr9-OJiBjZxr%7E%7EEE9VDANl%7EOtmYoqZKn6hmdimCNi6HFO6Gh0Nr5IA2dMbKv61rfScjK1RDSEy6g-HA7aGfINGwGQqEuAEiLKQYEfUEDLt9nIgFKXBbxYi9ZUcrf6N0lUov%7E-qixQxD0qGrzZX4cmCRs6rIB0P5oRWT-Kejo2qAckVr%7EK3YaB5m3n7z6ZwaXX6JEZik-0vGfmQiipPZPAtqT9NOT-RpjOFi0VOGn5xf3uZkSLGcL2rGGxbHldkdndK3lyIpB-PKo0ZrPWs4l5dnmQ__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.155.68.94, 18.155.68.128, 18.155.68.73, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.155.68.94|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2560323205 (2.4G) [binary/octet-stream]
# Saving to: ‘L12-D2560-init.pth’
#
# L12-D2560-init.pth  100%[===================>]   2.38G  11.0MB/s    in 5m 6s
#
# 2023-07-15 01:17:56 (7.98 MB/s) - ‘L12-D2560-init.pth’ saved [2560323205/2560323205]
#
# -rw-rw-r-- 1 picocreator picocreator 2.4G Jul 15 00:57 ../../../model/L12-D2560-init.pth

# %%
DEEPSPEED_STRAT="deepspeed_stage_2_offload"
GPU_DEVICES="auto"
ENABLE_WANDB=True
WANDB_PREFIX="(EXPERIMENTAL) TokenShift-Exp-A"

print("DEEPSPEED_STRAT:", DEEPSPEED_STRAT)
print("ENABLE_WANDB:", ENABLE_WANDB)
print("GPU_DEVICES:", GPU_DEVICES)

if ENABLE_WANDB:
    WANDB_MODE="online"
else:
    WANDB_MODE="disabled"

# Computing the notebook, and various paths
import os
NOTEBOOK_DIR=os.path.dirname(os.path.abspath("__file__"))
PROJECT_DIR=os.path.abspath(os.path.join(NOTEBOOK_DIR, "../../../"))
TRAINER_DIR=os.path.abspath(os.path.join(PROJECT_DIR, "./RWKV-v4neo/"))

print("NOTEBOOK_DIR:", NOTEBOOK_DIR)
print("TRAINER_DIR:", TRAINER_DIR)
print("PROJECT_DIR:", PROJECT_DIR)
# Out:
# DEEPSPEED_STRAT: deepspeed_stage_2_offload
# ENABLE_WANDB: False
# GPU_DEVICES: auto
# NOTEBOOK_DIR: /home/picocreator/rwkv-proj/rwkv5-tokenshift-experiment/notebook/experiment/tokenshift-exp
# TRAINER_DIR: /home/picocreator/rwkv-proj/rwkv5-tokenshift-experiment/RWKV-v4neo
# PROJECT_DIR: /home/picocreator/rwkv-proj/rwkv5-tokenshift-experiment

# %% [markdown]
# ## Stage 1 : Foundation model training

# %%
# Lets preload the requried dataset (enwiki_100k)
# !cd "{TRAINER_DIR}" && \
    python3 preload_dataset.py "{NOTEBOOK_DIR}/TokenShift-A-enwiki.yaml"
# Out:
# Found cached dataset parquet (/home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_100k-1359e81b212c2dd6/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 98.92it/s]
# Loading cached processed dataset at /home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_100k-1359e81b212c2dd6/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-197c10b1cc695da5_*_of_00016.arrow
# Loading cached processed dataset at /home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_100k-1359e81b212c2dd6/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-aa09da794e8d7304_*_of_00016.arrow

# %%
# Start the foundation model training
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python new_train.py fit \
        -c "{NOTEBOOK_DIR}/TokenShift-A-enwiki.yaml" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - Enwiki Foundation (ctx=4096, {DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}"
# Out:
# [2023-07-15 16:04:24,032] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1'
# /home/picocreator/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/fabric/utilities/seed.py:39: UserWarning: No seed found, seed set to 3961506885
#   rank_zero_warn(f"No seed found, seed set to {seed}")
# Global seed set to 3961506885
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/wkv_4096_bf16/build.ninja...
# Building extension module wkv_4096_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_4096_bf16...
# /home/picocreator/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/fabric/connector.py:555: UserWarning: bf16 is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       32
#    - num_nodes:               1
#    - num_devices:             1
#    - accumulate_grad_batches: 32
#    - effective_batch_size:    32
#
# Found cached dataset parquet (/home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_100k-1359e81b212c2dd6/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 99.46it/s]
# Loading cached processed dataset at /home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_100k-1359e81b212c2dd6/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-197c10b1cc695da5_*_of_00016.arrow
# Loading cached processed dataset at /home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_100k-1359e81b212c2dd6/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-aa09da794e8d7304_*_of_00016.arrow
# [rank: 0] Global seed set to 3961506885
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# [2023-07-15 16:04:38,596] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Enabling DeepSpeed BF16.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  6.000e-04 (0.0006)
#     - lr_final: 4.000e-04 (0.0004)
#
#  [WARNING]  cpu_adam cuda is missing or is incompatible with installed torch, only cpu ops can be compiled!
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/cpu_adam/build.ninja...
# Building extension module cpu_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 2.3009207248687744 seconds
# Loading `train_dataloader` to estimate number of stepping batches.
# Rank: 0 partition count [1, 1, 1] and sizes[(1280066560, False), (30720, False), (30720, False)]
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 128 M
# 1 | blocks | ModuleList | 1.0 B
# 2 | ln_out | LayerNorm  | 5.1 K
# 3 | head   | Linear     | 128 M
# --------------------------------------
# 1.3 B     Trainable params
# 0         Non-trainable params
# 1.3 B     Total params
# 5,120.512 Total estimated model params size (MB)
# Epoch 0:   0%|                                       | 0/135740 [00:00<?, ?it/s]xxxx shape:  [1, 5351, 2560]
# xxx shape:  [1, 5351, 2560]
# xx.shape:  [1, 1255, 2560]
# x.shape:  [1, 1255, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5351, 2560]
# xxx shape:  [1, 5351, 2560]
# xx.shape:  [1, 1255, 2560]
# x.shape:  [1, 1255, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5351, 2560]
# xxx shape:  [1, 5351, 2560]
# xx.shape:  [1, 1255, 2560]
# x.shape:  [1, 1255, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5351, 2560]
# xxx shape:  [1, 5351, 2560]
# xx.shape:  [1, 1255, 2560]
# x.shape:  [1, 1255, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5351, 2560]
# xxx shape:  [1, 5351, 2560]
# xx.shape:  [1, 1255, 2560]
# x.shape:  [1, 1255, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5351, 2560]
# xxx shape:  [1, 5351, 2560]
# xx.shape:  [1, 1255, 2560]
# x.shape:  [1, 1255, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5351, 2560]
# xxx shape:  [1, 5351, 2560]
# xx.shape:  [1, 1255, 2560]
# x.shape:  [1, 1255, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5351, 2560]
# xxx shape:  [1, 5351, 2560]
# xx.shape:  [1, 1255, 2560]
# x.shape:  [1, 1255, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5351, 2560]
# xxx shape:  [1, 5351, 2560]
# xx.shape:  [1, 1255, 2560]
# x.shape:  [1, 1255, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5351, 2560]
# xxx shape:  [1, 5351, 2560]
# xx.shape:  [1, 1255, 2560]
# x.shape:  [1, 1255, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5351, 2560]
# xxx shape:  [1, 5351, 2560]
# xx.shape:  [1, 1255, 2560]
# x.shape:  [1, 1255, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5351, 2560]
# xxx shape:  [1, 5351, 2560]
# xx.shape:  [1, 1255, 2560]
# x.shape:  [1, 1255, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5351, 2560]
# xxx shape:  [1, 5351, 2560]
# xx.shape:  [1, 1255, 2560]
# x.shape:  [1, 1255, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5351, 2560]
# xxx shape:  [1, 5351, 2560]
# xx.shape:  [1, 1255, 2560]
# x.shape:  [1, 1255, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5351, 2560]
# xxx shape:  [1, 5351, 2560]
# xx.shape:  [1, 1255, 2560]
# x.shape:  [1, 1255, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5351, 2560]
# xxx shape:  [1, 5351, 2560]
# xx.shape:  [1, 1255, 2560]
# x.shape:  [1, 1255, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5351, 2560]
# xxx shape:  [1, 5351, 2560]
# xx.shape:  [1, 1255, 2560]
# x.shape:  [1, 1255, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5351, 2560]
# xxx shape:  [1, 5351, 2560]
# xx.shape:  [1, 1255, 2560]
# x.shape:  [1, 1255, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5351, 2560]
# xxx shape:  [1, 5351, 2560]
# xx.shape:  [1, 1255, 2560]
# x.shape:  [1, 1255, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5351, 2560]
# xxx shape:  [1, 5351, 2560]
# xx.shape:  [1, 1255, 2560]
# x.shape:  [1, 1255, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5351, 2560]
# xxx shape:  [1, 5351, 2560]
# xx.shape:  [1, 1255, 2560]
# x.shape:  [1, 1255, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5351, 2560]
# xxx shape:  [1, 5351, 2560]
# xx.shape:  [1, 1255, 2560]
# x.shape:  [1, 1255, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5351, 2560]
# xxx shape:  [1, 5351, 2560]
# xx.shape:  [1, 1255, 2560]
# x.shape:  [1, 1255, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5351, 2560]
# xxx shape:  [1, 5351, 2560]
# xx.shape:  [1, 1255, 2560]
# x.shape:  [1, 1255, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# Epoch 0:   0%| | 1/135740 [00:05<212:50:24,  5.64s/it, v_num=zolc, train/loss=10xxxx shape:  [1, 5969, 2560]
# xxx shape:  [1, 5969, 2560]
# xx.shape:  [1, 1873, 2560]
# x.shape:  [1, 1873, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5969, 2560]
# xxx shape:  [1, 5969, 2560]
# xx.shape:  [1, 1873, 2560]
# x.shape:  [1, 1873, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5969, 2560]
# xxx shape:  [1, 5969, 2560]
# xx.shape:  [1, 1873, 2560]
# x.shape:  [1, 1873, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5969, 2560]
# xxx shape:  [1, 5969, 2560]
# xx.shape:  [1, 1873, 2560]
# x.shape:  [1, 1873, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5969, 2560]
# xxx shape:  [1, 5969, 2560]
# xx.shape:  [1, 1873, 2560]
# x.shape:  [1, 1873, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5969, 2560]
# xxx shape:  [1, 5969, 2560]
# xx.shape:  [1, 1873, 2560]
# x.shape:  [1, 1873, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5969, 2560]
# xxx shape:  [1, 5969, 2560]
# xx.shape:  [1, 1873, 2560]
# x.shape:  [1, 1873, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5969, 2560]
# xxx shape:  [1, 5969, 2560]
# xx.shape:  [1, 1873, 2560]
# x.shape:  [1, 1873, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5969, 2560]
# xxx shape:  [1, 5969, 2560]
# xx.shape:  [1, 1873, 2560]
# x.shape:  [1, 1873, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5969, 2560]
# xxx shape:  [1, 5969, 2560]
# xx.shape:  [1, 1873, 2560]
# x.shape:  [1, 1873, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5969, 2560]
# xxx shape:  [1, 5969, 2560]
# xx.shape:  [1, 1873, 2560]
# x.shape:  [1, 1873, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5969, 2560]
# xxx shape:  [1, 5969, 2560]
# xx.shape:  [1, 1873, 2560]
# x.shape:  [1, 1873, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5969, 2560]
# xxx shape:  [1, 5969, 2560]
# xx.shape:  [1, 1873, 2560]
# x.shape:  [1, 1873, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5969, 2560]
# xxx shape:  [1, 5969, 2560]
# xx.shape:  [1, 1873, 2560]
# x.shape:  [1, 1873, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5969, 2560]
# xxx shape:  [1, 5969, 2560]
# xx.shape:  [1, 1873, 2560]
# x.shape:  [1, 1873, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5969, 2560]
# xxx shape:  [1, 5969, 2560]
# xx.shape:  [1, 1873, 2560]
# x.shape:  [1, 1873, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5969, 2560]
# xxx shape:  [1, 5969, 2560]
# xx.shape:  [1, 1873, 2560]
# x.shape:  [1, 1873, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5969, 2560]
# xxx shape:  [1, 5969, 2560]
# xx.shape:  [1, 1873, 2560]
# x.shape:  [1, 1873, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5969, 2560]
# xxx shape:  [1, 5969, 2560]
# xx.shape:  [1, 1873, 2560]
# x.shape:  [1, 1873, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5969, 2560]
# xxx shape:  [1, 5969, 2560]
# xx.shape:  [1, 1873, 2560]
# x.shape:  [1, 1873, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5969, 2560]
# xxx shape:  [1, 5969, 2560]
# xx.shape:  [1, 1873, 2560]
# x.shape:  [1, 1873, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5969, 2560]
# xxx shape:  [1, 5969, 2560]
# xx.shape:  [1, 1873, 2560]
# x.shape:  [1, 1873, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5969, 2560]
# xxx shape:  [1, 5969, 2560]
# xx.shape:  [1, 1873, 2560]
# x.shape:  [1, 1873, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5969, 2560]
# xxx shape:  [1, 5969, 2560]
# xx.shape:  [1, 1873, 2560]
# x.shape:  [1, 1873, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# Epoch 0:   0%| | 2/135740 [00:06<119:05:17,  3.16s/it, v_num=zolc, train/loss=10xxxx shape:  [1, 6626, 2560]
# xxx shape:  [1, 6626, 2560]
# xx.shape:  [1, 2530, 2560]
# x.shape:  [1, 2530, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6626, 2560]
# xxx shape:  [1, 6626, 2560]
# xx.shape:  [1, 2530, 2560]
# x.shape:  [1, 2530, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6626, 2560]
# xxx shape:  [1, 6626, 2560]
# xx.shape:  [1, 2530, 2560]
# x.shape:  [1, 2530, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6626, 2560]
# xxx shape:  [1, 6626, 2560]
# xx.shape:  [1, 2530, 2560]
# x.shape:  [1, 2530, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6626, 2560]
# xxx shape:  [1, 6626, 2560]
# xx.shape:  [1, 2530, 2560]
# x.shape:  [1, 2530, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6626, 2560]
# xxx shape:  [1, 6626, 2560]
# xx.shape:  [1, 2530, 2560]
# x.shape:  [1, 2530, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6626, 2560]
# xxx shape:  [1, 6626, 2560]
# xx.shape:  [1, 2530, 2560]
# x.shape:  [1, 2530, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6626, 2560]
# xxx shape:  [1, 6626, 2560]
# xx.shape:  [1, 2530, 2560]
# x.shape:  [1, 2530, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6626, 2560]
# xxx shape:  [1, 6626, 2560]
# xx.shape:  [1, 2530, 2560]
# x.shape:  [1, 2530, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6626, 2560]
# xxx shape:  [1, 6626, 2560]
# xx.shape:  [1, 2530, 2560]
# x.shape:  [1, 2530, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6626, 2560]
# xxx shape:  [1, 6626, 2560]
# xx.shape:  [1, 2530, 2560]
# x.shape:  [1, 2530, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6626, 2560]
# xxx shape:  [1, 6626, 2560]
# xx.shape:  [1, 2530, 2560]
# x.shape:  [1, 2530, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6625, 2560]
# xxx shape:  [1, 6625, 2560]
# xx.shape:  [1, 2529, 2560]
# x.shape:  [1, 2529, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6625, 2560]
# xxx shape:  [1, 6625, 2560]
# xx.shape:  [1, 2529, 2560]
# x.shape:  [1, 2529, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6625, 2560]
# xxx shape:  [1, 6625, 2560]
# xx.shape:  [1, 2529, 2560]
# x.shape:  [1, 2529, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6625, 2560]
# xxx shape:  [1, 6625, 2560]
# xx.shape:  [1, 2529, 2560]
# x.shape:  [1, 2529, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6625, 2560]
# xxx shape:  [1, 6625, 2560]
# xx.shape:  [1, 2529, 2560]
# x.shape:  [1, 2529, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6625, 2560]
# xxx shape:  [1, 6625, 2560]
# xx.shape:  [1, 2529, 2560]
# x.shape:  [1, 2529, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6625, 2560]
# xxx shape:  [1, 6625, 2560]
# xx.shape:  [1, 2529, 2560]
# x.shape:  [1, 2529, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6625, 2560]
# xxx shape:  [1, 6625, 2560]
# xx.shape:  [1, 2529, 2560]
# x.shape:  [1, 2529, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6625, 2560]
# xxx shape:  [1, 6625, 2560]
# xx.shape:  [1, 2529, 2560]
# x.shape:  [1, 2529, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6625, 2560]
# xxx shape:  [1, 6625, 2560]
# xx.shape:  [1, 2529, 2560]
# x.shape:  [1, 2529, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6625, 2560]
# xxx shape:  [1, 6625, 2560]
# xx.shape:  [1, 2529, 2560]
# x.shape:  [1, 2529, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6625, 2560]
# xxx shape:  [1, 6625, 2560]
# xx.shape:  [1, 2529, 2560]
# x.shape:  [1, 2529, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6625, 2560]
# xxx shape:  [1, 6625, 2560]
# xx.shape:  [1, 2529, 2560]
# x.shape:  [1, 2529, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6625, 2560]
# xxx shape:  [1, 6625, 2560]
# xx.shape:  [1, 2529, 2560]
# x.shape:  [1, 2529, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6625, 2560]
# xxx shape:  [1, 6625, 2560]
# xx.shape:  [1, 2529, 2560]
# x.shape:  [1, 2529, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6625, 2560]
# xxx shape:  [1, 6625, 2560]
# xx.shape:  [1, 2529, 2560]
# x.shape:  [1, 2529, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6625, 2560]
# xxx shape:  [1, 6625, 2560]
# xx.shape:  [1, 2529, 2560]
# x.shape:  [1, 2529, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6625, 2560]
# xxx shape:  [1, 6625, 2560]
# xx.shape:  [1, 2529, 2560]
# x.shape:  [1, 2529, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6625, 2560]
# xxx shape:  [1, 6625, 2560]
# xx.shape:  [1, 2529, 2560]
# x.shape:  [1, 2529, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6625, 2560]
# xxx shape:  [1, 6625, 2560]
# xx.shape:  [1, 2529, 2560]
# x.shape:  [1, 2529, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6625, 2560]
# xxx shape:  [1, 6625, 2560]
# xx.shape:  [1, 2529, 2560]
# x.shape:  [1, 2529, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6625, 2560]
# xxx shape:  [1, 6625, 2560]
# xx.shape:  [1, 2529, 2560]
# x.shape:  [1, 2529, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6625, 2560]
# xxx shape:  [1, 6625, 2560]
# xx.shape:  [1, 2529, 2560]
# x.shape:  [1, 2529, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6625, 2560]
# xxx shape:  [1, 6625, 2560]
# xx.shape:  [1, 2529, 2560]
# x.shape:  [1, 2529, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# Epoch 0:   0%| | 3/135740 [00:07<97:15:27,  2.58s/it, v_num=zolc, train/loss=10.xxxx shape:  [1, 5223, 2560]
# xxx shape:  [1, 5223, 2560]
# xx.shape:  [1, 1127, 2560]
# x.shape:  [1, 1127, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5223, 2560]
# xxx shape:  [1, 5223, 2560]
# xx.shape:  [1, 1127, 2560]
# x.shape:  [1, 1127, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5223, 2560]
# xxx shape:  [1, 5223, 2560]
# xx.shape:  [1, 1127, 2560]
# x.shape:  [1, 1127, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5223, 2560]
# xxx shape:  [1, 5223, 2560]
# xx.shape:  [1, 1127, 2560]
# x.shape:  [1, 1127, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5223, 2560]
# xxx shape:  [1, 5223, 2560]
# xx.shape:  [1, 1127, 2560]
# x.shape:  [1, 1127, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5223, 2560]
# xxx shape:  [1, 5223, 2560]
# xx.shape:  [1, 1127, 2560]
# x.shape:  [1, 1127, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5223, 2560]
# xxx shape:  [1, 5223, 2560]
# xx.shape:  [1, 1127, 2560]
# x.shape:  [1, 1127, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5223, 2560]
# xxx shape:  [1, 5223, 2560]
# xx.shape:  [1, 1127, 2560]
# x.shape:  [1, 1127, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5223, 2560]
# xxx shape:  [1, 5223, 2560]
# xx.shape:  [1, 1127, 2560]
# x.shape:  [1, 1127, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5223, 2560]
# xxx shape:  [1, 5223, 2560]
# xx.shape:  [1, 1127, 2560]
# x.shape:  [1, 1127, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5223, 2560]
# xxx shape:  [1, 5223, 2560]
# xx.shape:  [1, 1127, 2560]
# x.shape:  [1, 1127, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5223, 2560]
# xxx shape:  [1, 5223, 2560]
# xx.shape:  [1, 1127, 2560]
# x.shape:  [1, 1127, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5223, 2560]
# xxx shape:  [1, 5223, 2560]
# xx.shape:  [1, 1127, 2560]
# x.shape:  [1, 1127, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5223, 2560]
# xxx shape:  [1, 5223, 2560]
# xx.shape:  [1, 1127, 2560]
# x.shape:  [1, 1127, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5223, 2560]
# xxx shape:  [1, 5223, 2560]
# xx.shape:  [1, 1127, 2560]
# x.shape:  [1, 1127, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5223, 2560]
# xxx shape:  [1, 5223, 2560]
# xx.shape:  [1, 1127, 2560]
# x.shape:  [1, 1127, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5223, 2560]
# xxx shape:  [1, 5223, 2560]
# xx.shape:  [1, 1127, 2560]
# x.shape:  [1, 1127, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5223, 2560]
# xxx shape:  [1, 5223, 2560]
# xx.shape:  [1, 1127, 2560]
# x.shape:  [1, 1127, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5223, 2560]
# xxx shape:  [1, 5223, 2560]
# xx.shape:  [1, 1127, 2560]
# x.shape:  [1, 1127, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5223, 2560]
# xxx shape:  [1, 5223, 2560]
# xx.shape:  [1, 1127, 2560]
# x.shape:  [1, 1127, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5223, 2560]
# xxx shape:  [1, 5223, 2560]
# xx.shape:  [1, 1127, 2560]
# x.shape:  [1, 1127, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5223, 2560]
# xxx shape:  [1, 5223, 2560]
# xx.shape:  [1, 1127, 2560]
# x.shape:  [1, 1127, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5223, 2560]
# xxx shape:  [1, 5223, 2560]
# xx.shape:  [1, 1127, 2560]
# x.shape:  [1, 1127, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5223, 2560]
# xxx shape:  [1, 5223, 2560]
# xx.shape:  [1, 1127, 2560]
# x.shape:  [1, 1127, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# Epoch 0:   0%| | 4/135740 [00:08<76:27:08,  2.03s/it, v_num=zolc, train/loss=10.xxxx shape:  [1, 5783, 2560]
# xxx shape:  [1, 5783, 2560]
# xx.shape:  [1, 1687, 2560]
# x.shape:  [1, 1687, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5783, 2560]
# xxx shape:  [1, 5783, 2560]
# xx.shape:  [1, 1687, 2560]
# x.shape:  [1, 1687, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5783, 2560]
# xxx shape:  [1, 5783, 2560]
# xx.shape:  [1, 1687, 2560]
# x.shape:  [1, 1687, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5783, 2560]
# xxx shape:  [1, 5783, 2560]
# xx.shape:  [1, 1687, 2560]
# x.shape:  [1, 1687, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5783, 2560]
# xxx shape:  [1, 5783, 2560]
# xx.shape:  [1, 1687, 2560]
# x.shape:  [1, 1687, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5783, 2560]
# xxx shape:  [1, 5783, 2560]
# xx.shape:  [1, 1687, 2560]
# x.shape:  [1, 1687, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5783, 2560]
# xxx shape:  [1, 5783, 2560]
# xx.shape:  [1, 1687, 2560]
# x.shape:  [1, 1687, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5783, 2560]
# xxx shape:  [1, 5783, 2560]
# xx.shape:  [1, 1687, 2560]
# x.shape:  [1, 1687, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5783, 2560]
# xxx shape:  [1, 5783, 2560]
# xx.shape:  [1, 1687, 2560]
# x.shape:  [1, 1687, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5783, 2560]
# xxx shape:  [1, 5783, 2560]
# xx.shape:  [1, 1687, 2560]
# x.shape:  [1, 1687, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5783, 2560]
# xxx shape:  [1, 5783, 2560]
# xx.shape:  [1, 1687, 2560]
# x.shape:  [1, 1687, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5783, 2560]
# xxx shape:  [1, 5783, 2560]
# xx.shape:  [1, 1687, 2560]
# x.shape:  [1, 1687, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5783, 2560]
# xxx shape:  [1, 5783, 2560]
# xx.shape:  [1, 1687, 2560]
# x.shape:  [1, 1687, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5783, 2560]
# xxx shape:  [1, 5783, 2560]
# xx.shape:  [1, 1687, 2560]
# x.shape:  [1, 1687, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5783, 2560]
# xxx shape:  [1, 5783, 2560]
# xx.shape:  [1, 1687, 2560]
# x.shape:  [1, 1687, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5783, 2560]
# xxx shape:  [1, 5783, 2560]
# xx.shape:  [1, 1687, 2560]
# x.shape:  [1, 1687, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5783, 2560]
# xxx shape:  [1, 5783, 2560]
# xx.shape:  [1, 1687, 2560]
# x.shape:  [1, 1687, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5783, 2560]
# xxx shape:  [1, 5783, 2560]
# xx.shape:  [1, 1687, 2560]
# x.shape:  [1, 1687, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5783, 2560]
# xxx shape:  [1, 5783, 2560]
# xx.shape:  [1, 1687, 2560]
# x.shape:  [1, 1687, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5783, 2560]
# xxx shape:  [1, 5783, 2560]
# xx.shape:  [1, 1687, 2560]
# x.shape:  [1, 1687, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5783, 2560]
# xxx shape:  [1, 5783, 2560]
# xx.shape:  [1, 1687, 2560]
# x.shape:  [1, 1687, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5783, 2560]
# xxx shape:  [1, 5783, 2560]
# xx.shape:  [1, 1687, 2560]
# x.shape:  [1, 1687, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5783, 2560]
# xxx shape:  [1, 5783, 2560]
# xx.shape:  [1, 1687, 2560]
# x.shape:  [1, 1687, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5783, 2560]
# xxx shape:  [1, 5783, 2560]
# xx.shape:  [1, 1687, 2560]
# x.shape:  [1, 1687, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# Epoch 0:   0%| | 5/135740 [00:08<64:06:56,  1.70s/it, v_num=zolc, train/loss=10.xxxx shape:  [1, 6127, 2560]
# xxx shape:  [1, 6127, 2560]
# xx.shape:  [1, 2031, 2560]
# x.shape:  [1, 2031, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6127, 2560]
# xxx shape:  [1, 6127, 2560]
# xx.shape:  [1, 2031, 2560]
# x.shape:  [1, 2031, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6127, 2560]
# xxx shape:  [1, 6127, 2560]
# xx.shape:  [1, 2031, 2560]
# x.shape:  [1, 2031, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6127, 2560]
# xxx shape:  [1, 6127, 2560]
# xx.shape:  [1, 2031, 2560]
# x.shape:  [1, 2031, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6127, 2560]
# xxx shape:  [1, 6127, 2560]
# xx.shape:  [1, 2031, 2560]
# x.shape:  [1, 2031, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6127, 2560]
# xxx shape:  [1, 6127, 2560]
# xx.shape:  [1, 2031, 2560]
# x.shape:  [1, 2031, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6127, 2560]
# xxx shape:  [1, 6127, 2560]
# xx.shape:  [1, 2031, 2560]
# x.shape:  [1, 2031, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6127, 2560]
# xxx shape:  [1, 6127, 2560]
# xx.shape:  [1, 2031, 2560]
# x.shape:  [1, 2031, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6127, 2560]
# xxx shape:  [1, 6127, 2560]
# xx.shape:  [1, 2031, 2560]
# x.shape:  [1, 2031, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6127, 2560]
# xxx shape:  [1, 6127, 2560]
# xx.shape:  [1, 2031, 2560]
# x.shape:  [1, 2031, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6127, 2560]
# xxx shape:  [1, 6127, 2560]
# xx.shape:  [1, 2031, 2560]
# x.shape:  [1, 2031, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6127, 2560]
# xxx shape:  [1, 6127, 2560]
# xx.shape:  [1, 2031, 2560]
# x.shape:  [1, 2031, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6127, 2560]
# xxx shape:  [1, 6127, 2560]
# xx.shape:  [1, 2031, 2560]
# x.shape:  [1, 2031, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6127, 2560]
# xxx shape:  [1, 6127, 2560]
# xx.shape:  [1, 2031, 2560]
# x.shape:  [1, 2031, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6127, 2560]
# xxx shape:  [1, 6127, 2560]
# xx.shape:  [1, 2031, 2560]
# x.shape:  [1, 2031, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6127, 2560]
# xxx shape:  [1, 6127, 2560]
# xx.shape:  [1, 2031, 2560]
# x.shape:  [1, 2031, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6127, 2560]
# xxx shape:  [1, 6127, 2560]
# xx.shape:  [1, 2031, 2560]
# x.shape:  [1, 2031, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6127, 2560]
# xxx shape:  [1, 6127, 2560]
# xx.shape:  [1, 2031, 2560]
# x.shape:  [1, 2031, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6127, 2560]
# xxx shape:  [1, 6127, 2560]
# xx.shape:  [1, 2031, 2560]
# x.shape:  [1, 2031, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6127, 2560]
# xxx shape:  [1, 6127, 2560]
# xx.shape:  [1, 2031, 2560]
# x.shape:  [1, 2031, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6127, 2560]
# xxx shape:  [1, 6127, 2560]
# xx.shape:  [1, 2031, 2560]
# x.shape:  [1, 2031, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6127, 2560]
# xxx shape:  [1, 6127, 2560]
# xx.shape:  [1, 2031, 2560]
# x.shape:  [1, 2031, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6127, 2560]
# xxx shape:  [1, 6127, 2560]
# xx.shape:  [1, 2031, 2560]
# x.shape:  [1, 2031, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6127, 2560]
# xxx shape:  [1, 6127, 2560]
# xx.shape:  [1, 2031, 2560]
# x.shape:  [1, 2031, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# Epoch 0:   0%| | 6/135740 [00:08<55:48:15,  1.48s/it, v_num=zolc, train/loss=10.xxxx shape:  [1, 6572, 2560]
# xxx shape:  [1, 6572, 2560]
# xx.shape:  [1, 2476, 2560]
# x.shape:  [1, 2476, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6572, 2560]
# xxx shape:  [1, 6572, 2560]
# xx.shape:  [1, 2476, 2560]
# x.shape:  [1, 2476, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6572, 2560]
# xxx shape:  [1, 6572, 2560]
# xx.shape:  [1, 2476, 2560]
# x.shape:  [1, 2476, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6572, 2560]
# xxx shape:  [1, 6572, 2560]
# xx.shape:  [1, 2476, 2560]
# x.shape:  [1, 2476, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6572, 2560]
# xxx shape:  [1, 6572, 2560]
# xx.shape:  [1, 2476, 2560]
# x.shape:  [1, 2476, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6572, 2560]
# xxx shape:  [1, 6572, 2560]
# xx.shape:  [1, 2476, 2560]
# x.shape:  [1, 2476, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6572, 2560]
# xxx shape:  [1, 6572, 2560]
# xx.shape:  [1, 2476, 2560]
# x.shape:  [1, 2476, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6572, 2560]
# xxx shape:  [1, 6572, 2560]
# xx.shape:  [1, 2476, 2560]
# x.shape:  [1, 2476, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6572, 2560]
# xxx shape:  [1, 6572, 2560]
# xx.shape:  [1, 2476, 2560]
# x.shape:  [1, 2476, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6572, 2560]
# xxx shape:  [1, 6572, 2560]
# xx.shape:  [1, 2476, 2560]
# x.shape:  [1, 2476, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6572, 2560]
# xxx shape:  [1, 6572, 2560]
# xx.shape:  [1, 2476, 2560]
# x.shape:  [1, 2476, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6572, 2560]
# xxx shape:  [1, 6572, 2560]
# xx.shape:  [1, 2476, 2560]
# x.shape:  [1, 2476, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6572, 2560]
# xxx shape:  [1, 6572, 2560]
# xx.shape:  [1, 2476, 2560]
# x.shape:  [1, 2476, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6572, 2560]
# xxx shape:  [1, 6572, 2560]
# xx.shape:  [1, 2476, 2560]
# x.shape:  [1, 2476, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6572, 2560]
# xxx shape:  [1, 6572, 2560]
# xx.shape:  [1, 2476, 2560]
# x.shape:  [1, 2476, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6572, 2560]
# xxx shape:  [1, 6572, 2560]
# xx.shape:  [1, 2476, 2560]
# x.shape:  [1, 2476, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6572, 2560]
# xxx shape:  [1, 6572, 2560]
# xx.shape:  [1, 2476, 2560]
# x.shape:  [1, 2476, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6572, 2560]
# xxx shape:  [1, 6572, 2560]
# xx.shape:  [1, 2476, 2560]
# x.shape:  [1, 2476, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6572, 2560]
# xxx shape:  [1, 6572, 2560]
# xx.shape:  [1, 2476, 2560]
# x.shape:  [1, 2476, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6572, 2560]
# xxx shape:  [1, 6572, 2560]
# xx.shape:  [1, 2476, 2560]
# x.shape:  [1, 2476, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6572, 2560]
# xxx shape:  [1, 6572, 2560]
# xx.shape:  [1, 2476, 2560]
# x.shape:  [1, 2476, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6572, 2560]
# xxx shape:  [1, 6572, 2560]
# xx.shape:  [1, 2476, 2560]
# x.shape:  [1, 2476, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6572, 2560]
# xxx shape:  [1, 6572, 2560]
# xx.shape:  [1, 2476, 2560]
# x.shape:  [1, 2476, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6572, 2560]
# xxx shape:  [1, 6572, 2560]
# xx.shape:  [1, 2476, 2560]
# x.shape:  [1, 2476, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# Epoch 0:   0%| | 7/135740 [00:09<49:55:05,  1.32s/it, v_num=zolc, train/loss=10.xxxx shape:  [1, 5621, 2560]
# xxx shape:  [1, 5621, 2560]
# xx.shape:  [1, 1525, 2560]
# x.shape:  [1, 1525, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5621, 2560]
# xxx shape:  [1, 5621, 2560]
# xx.shape:  [1, 1525, 2560]
# x.shape:  [1, 1525, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5621, 2560]
# xxx shape:  [1, 5621, 2560]
# xx.shape:  [1, 1525, 2560]
# x.shape:  [1, 1525, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5621, 2560]
# xxx shape:  [1, 5621, 2560]
# xx.shape:  [1, 1525, 2560]
# x.shape:  [1, 1525, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5621, 2560]
# xxx shape:  [1, 5621, 2560]
# xx.shape:  [1, 1525, 2560]
# x.shape:  [1, 1525, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5621, 2560]
# xxx shape:  [1, 5621, 2560]
# xx.shape:  [1, 1525, 2560]
# x.shape:  [1, 1525, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5621, 2560]
# xxx shape:  [1, 5621, 2560]
# xx.shape:  [1, 1525, 2560]
# x.shape:  [1, 1525, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5621, 2560]
# xxx shape:  [1, 5621, 2560]
# xx.shape:  [1, 1525, 2560]
# x.shape:  [1, 1525, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5621, 2560]
# xxx shape:  [1, 5621, 2560]
# xx.shape:  [1, 1525, 2560]
# x.shape:  [1, 1525, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5621, 2560]
# xxx shape:  [1, 5621, 2560]
# xx.shape:  [1, 1525, 2560]
# x.shape:  [1, 1525, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5621, 2560]
# xxx shape:  [1, 5621, 2560]
# xx.shape:  [1, 1525, 2560]
# x.shape:  [1, 1525, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5621, 2560]
# xxx shape:  [1, 5621, 2560]
# xx.shape:  [1, 1525, 2560]
# x.shape:  [1, 1525, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5621, 2560]
# xxx shape:  [1, 5621, 2560]
# xx.shape:  [1, 1525, 2560]
# x.shape:  [1, 1525, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5621, 2560]
# xxx shape:  [1, 5621, 2560]
# xx.shape:  [1, 1525, 2560]
# x.shape:  [1, 1525, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5621, 2560]
# xxx shape:  [1, 5621, 2560]
# xx.shape:  [1, 1525, 2560]
# x.shape:  [1, 1525, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5621, 2560]
# xxx shape:  [1, 5621, 2560]
# xx.shape:  [1, 1525, 2560]
# x.shape:  [1, 1525, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5621, 2560]
# xxx shape:  [1, 5621, 2560]
# xx.shape:  [1, 1525, 2560]
# x.shape:  [1, 1525, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5621, 2560]
# xxx shape:  [1, 5621, 2560]
# xx.shape:  [1, 1525, 2560]
# x.shape:  [1, 1525, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5621, 2560]
# xxx shape:  [1, 5621, 2560]
# xx.shape:  [1, 1525, 2560]
# x.shape:  [1, 1525, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5621, 2560]
# xxx shape:  [1, 5621, 2560]
# xx.shape:  [1, 1525, 2560]
# x.shape:  [1, 1525, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5621, 2560]
# xxx shape:  [1, 5621, 2560]
# xx.shape:  [1, 1525, 2560]
# x.shape:  [1, 1525, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5621, 2560]
# xxx shape:  [1, 5621, 2560]
# xx.shape:  [1, 1525, 2560]
# x.shape:  [1, 1525, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5621, 2560]
# xxx shape:  [1, 5621, 2560]
# xx.shape:  [1, 1525, 2560]
# x.shape:  [1, 1525, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5621, 2560]
# xxx shape:  [1, 5621, 2560]
# xx.shape:  [1, 1525, 2560]
# x.shape:  [1, 1525, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# Epoch 0:   0%| | 8/135740 [00:09<45:25:25,  1.20s/it, v_num=zolc, train/loss=10.xxxx shape:  [1, 5408, 2560]
# xxx shape:  [1, 5408, 2560]
# xx.shape:  [1, 1312, 2560]
# x.shape:  [1, 1312, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5408, 2560]
# xxx shape:  [1, 5408, 2560]
# xx.shape:  [1, 1312, 2560]
# x.shape:  [1, 1312, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5408, 2560]
# xxx shape:  [1, 5408, 2560]
# xx.shape:  [1, 1312, 2560]
# x.shape:  [1, 1312, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5408, 2560]
# xxx shape:  [1, 5408, 2560]
# xx.shape:  [1, 1312, 2560]
# x.shape:  [1, 1312, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5408, 2560]
# xxx shape:  [1, 5408, 2560]
# xx.shape:  [1, 1312, 2560]
# x.shape:  [1, 1312, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5408, 2560]
# xxx shape:  [1, 5408, 2560]
# xx.shape:  [1, 1312, 2560]
# x.shape:  [1, 1312, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5408, 2560]
# xxx shape:  [1, 5408, 2560]
# xx.shape:  [1, 1312, 2560]
# x.shape:  [1, 1312, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5408, 2560]
# xxx shape:  [1, 5408, 2560]
# xx.shape:  [1, 1312, 2560]
# x.shape:  [1, 1312, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5408, 2560]
# xxx shape:  [1, 5408, 2560]
# xx.shape:  [1, 1312, 2560]
# x.shape:  [1, 1312, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5408, 2560]
# xxx shape:  [1, 5408, 2560]
# xx.shape:  [1, 1312, 2560]
# x.shape:  [1, 1312, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5408, 2560]
# xxx shape:  [1, 5408, 2560]
# xx.shape:  [1, 1312, 2560]
# x.shape:  [1, 1312, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5408, 2560]
# xxx shape:  [1, 5408, 2560]
# xx.shape:  [1, 1312, 2560]
# x.shape:  [1, 1312, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5408, 2560]
# xxx shape:  [1, 5408, 2560]
# xx.shape:  [1, 1312, 2560]
# x.shape:  [1, 1312, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5408, 2560]
# xxx shape:  [1, 5408, 2560]
# xx.shape:  [1, 1312, 2560]
# x.shape:  [1, 1312, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5408, 2560]
# xxx shape:  [1, 5408, 2560]
# xx.shape:  [1, 1312, 2560]
# x.shape:  [1, 1312, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5408, 2560]
# xxx shape:  [1, 5408, 2560]
# xx.shape:  [1, 1312, 2560]
# x.shape:  [1, 1312, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5408, 2560]
# xxx shape:  [1, 5408, 2560]
# xx.shape:  [1, 1312, 2560]
# x.shape:  [1, 1312, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5408, 2560]
# xxx shape:  [1, 5408, 2560]
# xx.shape:  [1, 1312, 2560]
# x.shape:  [1, 1312, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5408, 2560]
# xxx shape:  [1, 5408, 2560]
# xx.shape:  [1, 1312, 2560]
# x.shape:  [1, 1312, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5408, 2560]
# xxx shape:  [1, 5408, 2560]
# xx.shape:  [1, 1312, 2560]
# x.shape:  [1, 1312, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5408, 2560]
# xxx shape:  [1, 5408, 2560]
# xx.shape:  [1, 1312, 2560]
# x.shape:  [1, 1312, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5408, 2560]
# xxx shape:  [1, 5408, 2560]
# xx.shape:  [1, 1312, 2560]
# x.shape:  [1, 1312, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5408, 2560]
# xxx shape:  [1, 5408, 2560]
# xx.shape:  [1, 1312, 2560]
# x.shape:  [1, 1312, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5408, 2560]
# xxx shape:  [1, 5408, 2560]
# xx.shape:  [1, 1312, 2560]
# x.shape:  [1, 1312, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# Epoch 0:   0%| | 9/135740 [00:10<41:55:20,  1.11s/it, v_num=zolc, train/loss=10.xxxx shape:  [1, 5316, 2560]
# xxx shape:  [1, 5316, 2560]
# xx.shape:  [1, 1220, 2560]
# x.shape:  [1, 1220, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5316, 2560]
# xxx shape:  [1, 5316, 2560]
# xx.shape:  [1, 1220, 2560]
# x.shape:  [1, 1220, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5316, 2560]
# xxx shape:  [1, 5316, 2560]
# xx.shape:  [1, 1220, 2560]
# x.shape:  [1, 1220, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5316, 2560]
# xxx shape:  [1, 5316, 2560]
# xx.shape:  [1, 1220, 2560]
# x.shape:  [1, 1220, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5316, 2560]
# xxx shape:  [1, 5316, 2560]
# xx.shape:  [1, 1220, 2560]
# x.shape:  [1, 1220, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5316, 2560]
# xxx shape:  [1, 5316, 2560]
# xx.shape:  [1, 1220, 2560]
# x.shape:  [1, 1220, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5316, 2560]
# xxx shape:  [1, 5316, 2560]
# xx.shape:  [1, 1220, 2560]
# x.shape:  [1, 1220, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5316, 2560]
# xxx shape:  [1, 5316, 2560]
# xx.shape:  [1, 1220, 2560]
# x.shape:  [1, 1220, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5316, 2560]
# xxx shape:  [1, 5316, 2560]
# xx.shape:  [1, 1220, 2560]
# x.shape:  [1, 1220, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5316, 2560]
# xxx shape:  [1, 5316, 2560]
# xx.shape:  [1, 1220, 2560]
# x.shape:  [1, 1220, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5316, 2560]
# xxx shape:  [1, 5316, 2560]
# xx.shape:  [1, 1220, 2560]
# x.shape:  [1, 1220, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5316, 2560]
# xxx shape:  [1, 5316, 2560]
# xx.shape:  [1, 1220, 2560]
# x.shape:  [1, 1220, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5316, 2560]
# xxx shape:  [1, 5316, 2560]
# xx.shape:  [1, 1220, 2560]
# x.shape:  [1, 1220, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5316, 2560]
# xxx shape:  [1, 5316, 2560]
# xx.shape:  [1, 1220, 2560]
# x.shape:  [1, 1220, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5316, 2560]
# xxx shape:  [1, 5316, 2560]
# xx.shape:  [1, 1220, 2560]
# x.shape:  [1, 1220, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5316, 2560]
# xxx shape:  [1, 5316, 2560]
# xx.shape:  [1, 1220, 2560]
# x.shape:  [1, 1220, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5316, 2560]
# xxx shape:  [1, 5316, 2560]
# xx.shape:  [1, 1220, 2560]
# x.shape:  [1, 1220, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5316, 2560]
# xxx shape:  [1, 5316, 2560]
# xx.shape:  [1, 1220, 2560]
# x.shape:  [1, 1220, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5316, 2560]
# xxx shape:  [1, 5316, 2560]
# xx.shape:  [1, 1220, 2560]
# x.shape:  [1, 1220, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5316, 2560]
# xxx shape:  [1, 5316, 2560]
# xx.shape:  [1, 1220, 2560]
# x.shape:  [1, 1220, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5316, 2560]
# xxx shape:  [1, 5316, 2560]
# xx.shape:  [1, 1220, 2560]
# x.shape:  [1, 1220, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5316, 2560]
# xxx shape:  [1, 5316, 2560]
# xx.shape:  [1, 1220, 2560]
# x.shape:  [1, 1220, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5316, 2560]
# xxx shape:  [1, 5316, 2560]
# xx.shape:  [1, 1220, 2560]
# x.shape:  [1, 1220, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5316, 2560]
# xxx shape:  [1, 5316, 2560]
# xx.shape:  [1, 1220, 2560]
# x.shape:  [1, 1220, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# Epoch 0:   0%| | 10/135740 [00:10<39:07:30,  1.04s/it, v_num=zolc, train/loss=10xxxx shape:  [1, 5894, 2560]
# xxx shape:  [1, 5894, 2560]
# xx.shape:  [1, 1798, 2560]
# x.shape:  [1, 1798, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5894, 2560]
# xxx shape:  [1, 5894, 2560]
# xx.shape:  [1, 1798, 2560]
# x.shape:  [1, 1798, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5894, 2560]
# xxx shape:  [1, 5894, 2560]
# xx.shape:  [1, 1798, 2560]
# x.shape:  [1, 1798, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5894, 2560]
# xxx shape:  [1, 5894, 2560]
# xx.shape:  [1, 1798, 2560]
# x.shape:  [1, 1798, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5894, 2560]
# xxx shape:  [1, 5894, 2560]
# xx.shape:  [1, 1798, 2560]
# x.shape:  [1, 1798, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5894, 2560]
# xxx shape:  [1, 5894, 2560]
# xx.shape:  [1, 1798, 2560]
# x.shape:  [1, 1798, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5894, 2560]
# xxx shape:  [1, 5894, 2560]
# xx.shape:  [1, 1798, 2560]
# x.shape:  [1, 1798, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5894, 2560]
# xxx shape:  [1, 5894, 2560]
# xx.shape:  [1, 1798, 2560]
# x.shape:  [1, 1798, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5894, 2560]
# xxx shape:  [1, 5894, 2560]
# xx.shape:  [1, 1798, 2560]
# x.shape:  [1, 1798, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5894, 2560]
# xxx shape:  [1, 5894, 2560]
# xx.shape:  [1, 1798, 2560]
# x.shape:  [1, 1798, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5894, 2560]
# xxx shape:  [1, 5894, 2560]
# xx.shape:  [1, 1798, 2560]
# x.shape:  [1, 1798, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5894, 2560]
# xxx shape:  [1, 5894, 2560]
# xx.shape:  [1, 1798, 2560]
# x.shape:  [1, 1798, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5894, 2560]
# xxx shape:  [1, 5894, 2560]
# xx.shape:  [1, 1798, 2560]
# x.shape:  [1, 1798, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5894, 2560]
# xxx shape:  [1, 5894, 2560]
# xx.shape:  [1, 1798, 2560]
# x.shape:  [1, 1798, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5894, 2560]
# xxx shape:  [1, 5894, 2560]
# xx.shape:  [1, 1798, 2560]
# x.shape:  [1, 1798, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5894, 2560]
# xxx shape:  [1, 5894, 2560]
# xx.shape:  [1, 1798, 2560]
# x.shape:  [1, 1798, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5894, 2560]
# xxx shape:  [1, 5894, 2560]
# xx.shape:  [1, 1798, 2560]
# x.shape:  [1, 1798, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5894, 2560]
# xxx shape:  [1, 5894, 2560]
# xx.shape:  [1, 1798, 2560]
# x.shape:  [1, 1798, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5894, 2560]
# xxx shape:  [1, 5894, 2560]
# xx.shape:  [1, 1798, 2560]
# x.shape:  [1, 1798, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5894, 2560]
# xxx shape:  [1, 5894, 2560]
# xx.shape:  [1, 1798, 2560]
# x.shape:  [1, 1798, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5894, 2560]
# xxx shape:  [1, 5894, 2560]
# xx.shape:  [1, 1798, 2560]
# x.shape:  [1, 1798, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5894, 2560]
# xxx shape:  [1, 5894, 2560]
# xx.shape:  [1, 1798, 2560]
# x.shape:  [1, 1798, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5894, 2560]
# xxx shape:  [1, 5894, 2560]
# xx.shape:  [1, 1798, 2560]
# x.shape:  [1, 1798, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5894, 2560]
# xxx shape:  [1, 5894, 2560]
# xx.shape:  [1, 1798, 2560]
# x.shape:  [1, 1798, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# Epoch 0:   0%| | 11/135740 [00:10<36:51:19,  1.02it/s, v_num=zolc, train/loss=10xxxx shape:  [1, 5723, 2560]
# xxx shape:  [1, 5723, 2560]
# xx.shape:  [1, 1627, 2560]
# x.shape:  [1, 1627, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5723, 2560]
# xxx shape:  [1, 5723, 2560]
# xx.shape:  [1, 1627, 2560]
# x.shape:  [1, 1627, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5723, 2560]
# xxx shape:  [1, 5723, 2560]
# xx.shape:  [1, 1627, 2560]
# x.shape:  [1, 1627, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5723, 2560]
# xxx shape:  [1, 5723, 2560]
# xx.shape:  [1, 1627, 2560]
# x.shape:  [1, 1627, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5723, 2560]
# xxx shape:  [1, 5723, 2560]
# xx.shape:  [1, 1627, 2560]
# x.shape:  [1, 1627, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5723, 2560]
# xxx shape:  [1, 5723, 2560]
# xx.shape:  [1, 1627, 2560]
# x.shape:  [1, 1627, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5723, 2560]
# xxx shape:  [1, 5723, 2560]
# xx.shape:  [1, 1627, 2560]
# x.shape:  [1, 1627, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5723, 2560]
# xxx shape:  [1, 5723, 2560]
# xx.shape:  [1, 1627, 2560]
# x.shape:  [1, 1627, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5723, 2560]
# xxx shape:  [1, 5723, 2560]
# xx.shape:  [1, 1627, 2560]
# x.shape:  [1, 1627, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5723, 2560]
# xxx shape:  [1, 5723, 2560]
# xx.shape:  [1, 1627, 2560]
# x.shape:  [1, 1627, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5723, 2560]
# xxx shape:  [1, 5723, 2560]
# xx.shape:  [1, 1627, 2560]
# x.shape:  [1, 1627, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5723, 2560]
# xxx shape:  [1, 5723, 2560]
# xx.shape:  [1, 1627, 2560]
# x.shape:  [1, 1627, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5723, 2560]
# xxx shape:  [1, 5723, 2560]
# xx.shape:  [1, 1627, 2560]
# x.shape:  [1, 1627, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5723, 2560]
# xxx shape:  [1, 5723, 2560]
# xx.shape:  [1, 1627, 2560]
# x.shape:  [1, 1627, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5723, 2560]
# xxx shape:  [1, 5723, 2560]
# xx.shape:  [1, 1627, 2560]
# x.shape:  [1, 1627, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5723, 2560]
# xxx shape:  [1, 5723, 2560]
# xx.shape:  [1, 1627, 2560]
# x.shape:  [1, 1627, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5723, 2560]
# xxx shape:  [1, 5723, 2560]
# xx.shape:  [1, 1627, 2560]
# x.shape:  [1, 1627, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5723, 2560]
# xxx shape:  [1, 5723, 2560]
# xx.shape:  [1, 1627, 2560]
# x.shape:  [1, 1627, 2560]
# ...
# xx.shape:  [1, 3975, 2560]
# x.shape:  [1, 3975, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 8071, 2560]
# xxx shape:  [1, 8071, 2560]
# xx.shape:  [1, 3975, 2560]
# x.shape:  [1, 3975, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 8071, 2560]
# xxx shape:  [1, 8071, 2560]
# xx.shape:  [1, 3975, 2560]
# x.shape:  [1, 3975, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 8071, 2560]
# xxx shape:  [1, 8071, 2560]
# xx.shape:  [1, 3975, 2560]
# x.shape:  [1, 3975, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 8071, 2560]
# xxx shape:  [1, 8071, 2560]
# xx.shape:  [1, 3975, 2560]
# x.shape:  [1, 3975, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 8071, 2560]
# xxx shape:  [1, 8071, 2560]
# xx.shape:  [1, 3975, 2560]
# x.shape:  [1, 3975, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 8071, 2560]
# xxx shape:  [1, 8071, 2560]
# xx.shape:  [1, 3975, 2560]
# x.shape:  [1, 3975, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 8071, 2560]
# xxx shape:  [1, 8071, 2560]
# xx.shape:  [1, 3975, 2560]
# x.shape:  [1, 3975, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 8071, 2560]
# xxx shape:  [1, 8071, 2560]
# xx.shape:  [1, 3975, 2560]
# x.shape:  [1, 3975, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 8071, 2560]
# xxx shape:  [1, 8071, 2560]
# xx.shape:  [1, 3975, 2560]
# x.shape:  [1, 3975, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 8071, 2560]
# xxx shape:  [1, 8071, 2560]
# xx.shape:  [1, 3975, 2560]
# x.shape:  [1, 3975, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 8071, 2560]
# xxx shape:  [1, 8071, 2560]
# xx.shape:  [1, 3975, 2560]
# x.shape:  [1, 3975, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 8071, 2560]
# xxx shape:  [1, 8071, 2560]
# xx.shape:  [1, 3975, 2560]
# x.shape:  [1, 3975, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 8071, 2560]
# xxx shape:  [1, 8071, 2560]
# xx.shape:  [1, 3975, 2560]
# x.shape:  [1, 3975, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 8071, 2560]
# xxx shape:  [1, 8071, 2560]
# xx.shape:  [1, 3975, 2560]
# x.shape:  [1, 3975, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 8071, 2560]
# xxx shape:  [1, 8071, 2560]
# xx.shape:  [1, 3975, 2560]
# x.shape:  [1, 3975, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 8071, 2560]
# xxx shape:  [1, 8071, 2560]
# xx.shape:  [1, 3975, 2560]
# x.shape:  [1, 3975, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 8071, 2560]
# xxx shape:  [1, 8071, 2560]
# xx.shape:  [1, 3975, 2560]
# x.shape:  [1, 3975, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# Epoch 0:   0%| | 28/135740 [00:18<24:30:09,  1.54it/s, v_num=zolc, train/loss=10xxxx shape:  [1, 5955, 2560]
# xxx shape:  [1, 5955, 2560]
# xx.shape:  [1, 1859, 2560]
# x.shape:  [1, 1859, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5955, 2560]
# xxx shape:  [1, 5955, 2560]
# xx.shape:  [1, 1859, 2560]
# x.shape:  [1, 1859, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5955, 2560]
# xxx shape:  [1, 5955, 2560]
# xx.shape:  [1, 1859, 2560]
# x.shape:  [1, 1859, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5955, 2560]
# xxx shape:  [1, 5955, 2560]
# xx.shape:  [1, 1859, 2560]
# x.shape:  [1, 1859, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5955, 2560]
# xxx shape:  [1, 5955, 2560]
# xx.shape:  [1, 1859, 2560]
# x.shape:  [1, 1859, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5955, 2560]
# xxx shape:  [1, 5955, 2560]
# xx.shape:  [1, 1859, 2560]
# x.shape:  [1, 1859, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5955, 2560]
# xxx shape:  [1, 5955, 2560]
# xx.shape:  [1, 1859, 2560]
# x.shape:  [1, 1859, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5955, 2560]
# xxx shape:  [1, 5955, 2560]
# xx.shape:  [1, 1859, 2560]
# x.shape:  [1, 1859, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5955, 2560]
# xxx shape:  [1, 5955, 2560]
# xx.shape:  [1, 1859, 2560]
# x.shape:  [1, 1859, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5955, 2560]
# xxx shape:  [1, 5955, 2560]
# xx.shape:  [1, 1859, 2560]
# x.shape:  [1, 1859, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5955, 2560]
# xxx shape:  [1, 5955, 2560]
# xx.shape:  [1, 1859, 2560]
# x.shape:  [1, 1859, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5955, 2560]
# xxx shape:  [1, 5955, 2560]
# xx.shape:  [1, 1859, 2560]
# x.shape:  [1, 1859, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5955, 2560]
# xxx shape:  [1, 5955, 2560]
# xx.shape:  [1, 1859, 2560]
# x.shape:  [1, 1859, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5955, 2560]
# xxx shape:  [1, 5955, 2560]
# xx.shape:  [1, 1859, 2560]
# x.shape:  [1, 1859, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5955, 2560]
# xxx shape:  [1, 5955, 2560]
# xx.shape:  [1, 1859, 2560]
# x.shape:  [1, 1859, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5955, 2560]
# xxx shape:  [1, 5955, 2560]
# xx.shape:  [1, 1859, 2560]
# x.shape:  [1, 1859, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5955, 2560]
# xxx shape:  [1, 5955, 2560]
# xx.shape:  [1, 1859, 2560]
# x.shape:  [1, 1859, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5955, 2560]
# xxx shape:  [1, 5955, 2560]
# xx.shape:  [1, 1859, 2560]
# x.shape:  [1, 1859, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5955, 2560]
# xxx shape:  [1, 5955, 2560]
# xx.shape:  [1, 1859, 2560]
# x.shape:  [1, 1859, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5955, 2560]
# xxx shape:  [1, 5955, 2560]
# xx.shape:  [1, 1859, 2560]
# x.shape:  [1, 1859, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5955, 2560]
# xxx shape:  [1, 5955, 2560]
# xx.shape:  [1, 1859, 2560]
# x.shape:  [1, 1859, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5955, 2560]
# xxx shape:  [1, 5955, 2560]
# xx.shape:  [1, 1859, 2560]
# x.shape:  [1, 1859, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5955, 2560]
# xxx shape:  [1, 5955, 2560]
# xx.shape:  [1, 1859, 2560]
# x.shape:  [1, 1859, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5955, 2560]
# xxx shape:  [1, 5955, 2560]
# xx.shape:  [1, 1859, 2560]
# x.shape:  [1, 1859, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# Epoch 0:   0%| | 29/135740 [00:18<24:08:46,  1.56it/s, v_num=zolc, train/loss=10xxxx shape:  [1, 6093, 2560]
# xxx shape:  [1, 6093, 2560]
# xx.shape:  [1, 1997, 2560]
# x.shape:  [1, 1997, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6093, 2560]
# xxx shape:  [1, 6093, 2560]
# xx.shape:  [1, 1997, 2560]
# x.shape:  [1, 1997, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6093, 2560]
# xxx shape:  [1, 6093, 2560]
# xx.shape:  [1, 1997, 2560]
# x.shape:  [1, 1997, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6093, 2560]
# xxx shape:  [1, 6093, 2560]
# xx.shape:  [1, 1997, 2560]
# x.shape:  [1, 1997, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6093, 2560]
# xxx shape:  [1, 6093, 2560]
# xx.shape:  [1, 1997, 2560]
# x.shape:  [1, 1997, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6093, 2560]
# xxx shape:  [1, 6093, 2560]
# xx.shape:  [1, 1997, 2560]
# x.shape:  [1, 1997, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6093, 2560]
# xxx shape:  [1, 6093, 2560]
# xx.shape:  [1, 1997, 2560]
# x.shape:  [1, 1997, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6093, 2560]
# xxx shape:  [1, 6093, 2560]
# xx.shape:  [1, 1997, 2560]
# x.shape:  [1, 1997, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6093, 2560]
# xxx shape:  [1, 6093, 2560]
# xx.shape:  [1, 1997, 2560]
# x.shape:  [1, 1997, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6093, 2560]
# xxx shape:  [1, 6093, 2560]
# xx.shape:  [1, 1997, 2560]
# x.shape:  [1, 1997, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6093, 2560]
# xxx shape:  [1, 6093, 2560]
# xx.shape:  [1, 1997, 2560]
# x.shape:  [1, 1997, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6093, 2560]
# xxx shape:  [1, 6093, 2560]
# xx.shape:  [1, 1997, 2560]
# x.shape:  [1, 1997, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6093, 2560]
# xxx shape:  [1, 6093, 2560]
# xx.shape:  [1, 1997, 2560]
# x.shape:  [1, 1997, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6093, 2560]
# xxx shape:  [1, 6093, 2560]
# xx.shape:  [1, 1997, 2560]
# x.shape:  [1, 1997, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6093, 2560]
# xxx shape:  [1, 6093, 2560]
# xx.shape:  [1, 1997, 2560]
# x.shape:  [1, 1997, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6093, 2560]
# xxx shape:  [1, 6093, 2560]
# xx.shape:  [1, 1997, 2560]
# x.shape:  [1, 1997, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6093, 2560]
# xxx shape:  [1, 6093, 2560]
# xx.shape:  [1, 1997, 2560]
# x.shape:  [1, 1997, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6093, 2560]
# xxx shape:  [1, 6093, 2560]
# xx.shape:  [1, 1997, 2560]
# x.shape:  [1, 1997, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6093, 2560]
# xxx shape:  [1, 6093, 2560]
# xx.shape:  [1, 1997, 2560]
# x.shape:  [1, 1997, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6093, 2560]
# xxx shape:  [1, 6093, 2560]
# xx.shape:  [1, 1997, 2560]
# x.shape:  [1, 1997, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6093, 2560]
# xxx shape:  [1, 6093, 2560]
# xx.shape:  [1, 1997, 2560]
# x.shape:  [1, 1997, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6093, 2560]
# xxx shape:  [1, 6093, 2560]
# xx.shape:  [1, 1997, 2560]
# x.shape:  [1, 1997, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6093, 2560]
# xxx shape:  [1, 6093, 2560]
# xx.shape:  [1, 1997, 2560]
# x.shape:  [1, 1997, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 6093, 2560]
# xxx shape:  [1, 6093, 2560]
# xx.shape:  [1, 1997, 2560]
# x.shape:  [1, 1997, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# Epoch 0:   0%| | 30/135740 [00:18<23:48:51,  1.58it/s, v_num=zolc, train/loss=10xxxx shape:  [1, 5333, 2560]
# xxx shape:  [1, 5333, 2560]
# xx.shape:  [1, 1237, 2560]
# x.shape:  [1, 1237, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5333, 2560]
# xxx shape:  [1, 5333, 2560]
# xx.shape:  [1, 1237, 2560]
# x.shape:  [1, 1237, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5333, 2560]
# xxx shape:  [1, 5333, 2560]
# xx.shape:  [1, 1237, 2560]
# x.shape:  [1, 1237, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5333, 2560]
# xxx shape:  [1, 5333, 2560]
# xx.shape:  [1, 1237, 2560]
# x.shape:  [1, 1237, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5333, 2560]
# xxx shape:  [1, 5333, 2560]
# xx.shape:  [1, 1237, 2560]
# x.shape:  [1, 1237, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5333, 2560]
# xxx shape:  [1, 5333, 2560]
# xx.shape:  [1, 1237, 2560]
# x.shape:  [1, 1237, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5333, 2560]
# xxx shape:  [1, 5333, 2560]
# xx.shape:  [1, 1237, 2560]
# x.shape:  [1, 1237, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5333, 2560]
# xxx shape:  [1, 5333, 2560]
# xx.shape:  [1, 1237, 2560]
# x.shape:  [1, 1237, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5333, 2560]
# xxx shape:  [1, 5333, 2560]
# xx.shape:  [1, 1237, 2560]
# x.shape:  [1, 1237, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5333, 2560]
# xxx shape:  [1, 5333, 2560]
# xx.shape:  [1, 1237, 2560]
# x.shape:  [1, 1237, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5333, 2560]
# xxx shape:  [1, 5333, 2560]
# xx.shape:  [1, 1237, 2560]
# x.shape:  [1, 1237, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5333, 2560]
# xxx shape:  [1, 5333, 2560]
# xx.shape:  [1, 1237, 2560]
# x.shape:  [1, 1237, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5333, 2560]
# xxx shape:  [1, 5333, 2560]
# xx.shape:  [1, 1237, 2560]
# x.shape:  [1, 1237, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5333, 2560]
# xxx shape:  [1, 5333, 2560]
# xx.shape:  [1, 1237, 2560]
# x.shape:  [1, 1237, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5333, 2560]
# xxx shape:  [1, 5333, 2560]
# xx.shape:  [1, 1237, 2560]
# x.shape:  [1, 1237, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5333, 2560]
# xxx shape:  [1, 5333, 2560]
# xx.shape:  [1, 1237, 2560]
# x.shape:  [1, 1237, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5333, 2560]
# xxx shape:  [1, 5333, 2560]
# xx.shape:  [1, 1237, 2560]
# x.shape:  [1, 1237, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5333, 2560]
# xxx shape:  [1, 5333, 2560]
# xx.shape:  [1, 1237, 2560]
# x.shape:  [1, 1237, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5333, 2560]
# xxx shape:  [1, 5333, 2560]
# xx.shape:  [1, 1237, 2560]
# x.shape:  [1, 1237, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5333, 2560]
# xxx shape:  [1, 5333, 2560]
# xx.shape:  [1, 1237, 2560]
# x.shape:  [1, 1237, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5333, 2560]
# xxx shape:  [1, 5333, 2560]
# xx.shape:  [1, 1237, 2560]
# x.shape:  [1, 1237, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5333, 2560]
# xxx shape:  [1, 5333, 2560]
# xx.shape:  [1, 1237, 2560]
# x.shape:  [1, 1237, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5333, 2560]
# xxx shape:  [1, 5333, 2560]
# xx.shape:  [1, 1237, 2560]
# x.shape:  [1, 1237, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 5333, 2560]
# xxx shape:  [1, 5333, 2560]
# xx.shape:  [1, 1237, 2560]
# x.shape:  [1, 1237, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# Epoch 0:   0%| | 31/135740 [00:19<23:29:33,  1.60it/s, v_num=zolc, train/loss=10xxxx shape:  [1, 7042, 2560]
# xxx shape:  [1, 7042, 2560]
# xx.shape:  [1, 2946, 2560]
# x.shape:  [1, 2946, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 7042, 2560]
# xxx shape:  [1, 7042, 2560]
# xx.shape:  [1, 2946, 2560]
# x.shape:  [1, 2946, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 7042, 2560]
# xxx shape:  [1, 7042, 2560]
# xx.shape:  [1, 2946, 2560]
# x.shape:  [1, 2946, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 7042, 2560]
# xxx shape:  [1, 7042, 2560]
# xx.shape:  [1, 2946, 2560]
# x.shape:  [1, 2946, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 7042, 2560]
# xxx shape:  [1, 7042, 2560]
# xx.shape:  [1, 2946, 2560]
# x.shape:  [1, 2946, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 7042, 2560]
# xxx shape:  [1, 7042, 2560]
# xx.shape:  [1, 2946, 2560]
# x.shape:  [1, 2946, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 7042, 2560]
# xxx shape:  [1, 7042, 2560]
# xx.shape:  [1, 2946, 2560]
# x.shape:  [1, 2946, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 7042, 2560]
# xxx shape:  [1, 7042, 2560]
# xx.shape:  [1, 2946, 2560]
# x.shape:  [1, 2946, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 7042, 2560]
# xxx shape:  [1, 7042, 2560]
# xx.shape:  [1, 2946, 2560]
# x.shape:  [1, 2946, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 7042, 2560]
# xxx shape:  [1, 7042, 2560]
# xx.shape:  [1, 2946, 2560]
# x.shape:  [1, 2946, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 7042, 2560]
# xxx shape:  [1, 7042, 2560]
# xx.shape:  [1, 2946, 2560]
# x.shape:  [1, 2946, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 7042, 2560]
# xxx shape:  [1, 7042, 2560]
# xx.shape:  [1, 2946, 2560]
# x.shape:  [1, 2946, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 7042, 2560]
# xxx shape:  [1, 7042, 2560]
# xx.shape:  [1, 2946, 2560]
# x.shape:  [1, 2946, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# ^C
# xxxx shape:  [1, 7042, 2560]
# xxx shape:  [1, 7042, 2560]
# xx.shape:  [1, 2946, 2560]
# x.shape:  [1, 2946, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 7042, 2560]
# xxx shape:  [1, 7042, 2560]
# xx.shape:  [1, 2946, 2560]
# x.shape:  [1, 2946, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 7042, 2560]
# xxx shape:  [1, 7042, 2560]
# xx.shape:  [1, 2946, 2560]
# x.shape:  [1, 2946, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]
# xxxx shape:  [1, 7042, 2560]
# xxx shape:  [1, 7042, 2560]
# xx.shape:  [1, 2946, 2560]
# x.shape:  [1, 2946, 2560]
# self.time_mix_k.shape:  [1, 1, 2560]

# %%
# Lets export the model from the checkpoint
# !cd "{TRAINER_DIR}" && \
    python export_checkpoint.py "../checkpoint/TokenShift-A-enwiki/last.ckpt" "../model/TokenShift-A-Stage1.pth"
# !cd "{TRAINER_DIR}" && ls -alh "../model/TokenShift-A-Stage1.pth"

# %%
# # Lets do a quick dragon prompt validation
# !cd "{TRAINER_DIR}" && python3 dragon_test.py ../model/TokenShift-A-Stage1.pth "cuda fp32"

# %%
# # Lets do a quick memory test
# # (We dun expect this to work, as we have not finetune for memory recall, but its a baseline)
# !python3 ./memory_script/eval_memory_guided.py "{PROJECT_DIR}/model/TokenShift-A-Stage1.pth"

# %% [markdown]
# # Stage 2 : Instruct Tuning

# %%
# Lets preload the requried dataset
# !cd "{TRAINER_DIR}" && \
    python3 preload_dataset.py "{NOTEBOOK_DIR}/TokenShift-A-instruct.yaml"

# %%
# Start the instruct finetuning
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python new_train.py fit \
        -c "{NOTEBOOK_DIR}/TokenShift-A-instruct.yaml" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - Instruct (train-ctx=4096, {DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}"

# %%
# Lets export the model from the checkpoint
# !cd "{TRAINER_DIR}" && \
    python export_checkpoint.py "../checkpoint/TokenShift-A-instruct/last.ckpt" "../model/TokenShift-A-Stage2.pth"
# !cd "{TRAINER_DIR}" && ls -alh "../model/TokenShift-A-Stage2.pth"

# %%
# # Lets do a quick dragon prompt validation
# !cd "{TRAINER_DIR}" && python3 dragon_test.py "../model/TokenShift-A-Stage2.pth" "cuda fp32"

# %%
# # Lets do a quick memory test
# # (We dun expect this to work, as we have not finetune for memory recall, but its a baseline)
# !python3 ./memory_script/eval_memory_guided.py "{PROJECT_DIR}/model/TokenShift-A-Stage2.pth"
