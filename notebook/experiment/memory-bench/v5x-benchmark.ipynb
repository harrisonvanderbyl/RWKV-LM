# %% [markdown]
# ## V5X specific benchmark
#
# The following is bencmarks specific for v5x runs, using experimental code

# %% [markdown]
# ## TokenShift-A

# %%
# Lets download the custom models
# !mkdir -p ../../../model/
# !cd ../../../model/ && wget -nc "https://huggingface.co/picocreator/memory-size-experiment-for-rwkv/resolve/main/TokenShift-A-Tune3.pth"
# Out:
# --2023-07-20 00:31:20--  https://huggingface.co/picocreator/memory-size-experiment-for-rwkv/resolve/main/TokenShift-A-Tune3.pth
# Resolving huggingface.co (huggingface.co)... 13.33.33.110, 13.33.33.55, 13.33.33.20, ...
# Connecting to huggingface.co (huggingface.co)|13.33.33.110|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !ls ../../../model/
# Out:
# L12-D2560-init.pth  TokenShift-A-Tune1.pth  TokenShift-A-Tune3.pth

# %%
# Memory benchmarking
# !python3 ./memory_script/eval_model_memory_guided.py "../../../model/TokenShift-A-Tune3.pth" "./logs/TokenShift-A-Tune3.csv"
# Out:
# [2023-07-20 01:32:42,052] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1'
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/wkv_1024_bf16/build.ninja...
# Building extension module wkv_1024_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_1024_bf16...
# ###
# ### Model validation start ###
# ###
# ## Model validation for 5 tokens : 100.0% similarity, with 5 matched token, and 0 token mismatch
# ## Model validation for 10 tokens : 100.0% similarity, with 10 matched token, and 0 token mismatch
# ...

# %%
# Lets download the custom models
# !mkdir -p ../../../model/
# !cd ../../../model/ && wget "https://huggingface.co/picocreator/memory-size-experiment-for-rwkv/resolve/main/TokenShift-A-Tune4.pth"
# Out:
# --2023-07-20 04:24:49--  https://huggingface.co/picocreator/memory-size-experiment-for-rwkv/resolve/main/TokenShift-A-Tune4.pth
# Resolving huggingface.co (huggingface.co)... 13.33.33.110, 13.33.33.55, 13.33.33.20, ...
# Connecting to huggingface.co (huggingface.co)|13.33.33.110|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# Memory benchmarking
# !python3 ./memory_script/eval_model_memory_guided.py "../../../model/TokenShift-A-Tune4.pth" "./logs/TokenShift-A-Tune4.csv"
# Out:
# [2023-07-20 04:32:24,669] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1'
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/wkv_1024_bf16/build.ninja...
# Building extension module wkv_1024_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_1024_bf16...
# ###
# ### Model validation start ###
# ###
# ## Model validation for 5 tokens : 100.0% similarity, with 5 matched token, and 0 token mismatch
# ## Model validation for 10 tokens : 100.0% similarity, with 10 matched token, and 0 token mismatch
# ...

# %% [markdown]
# ## TokenShift-B

# %%
# Lets download the custom models
# !mkdir -p ../../../model/
# !cd ../../../model/ && wget -nc "https://huggingface.co/picocreator/memory-size-experiment-for-rwkv/resolve/main/TokenShift-B-Tune3.pth"
# Out:
# --2023-07-20 21:26:54--  https://huggingface.co/picocreator/memory-size-experiment-for-rwkv/resolve/main/TokenShift-B-Tune3.pth
# Resolving huggingface.co (huggingface.co)... 13.224.249.44, 13.224.249.10, 13.224.249.43, ...
# Connecting to huggingface.co (huggingface.co)|13.224.249.44|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# Memory benchmarking
# !python3 ./memory_script/eval_model_memory_guided.py "../../../model/TokenShift-B-Tune3.pth" "./logs/TokenShift-B-Tune3.csv"
# Out:
# [2023-07-20 21:38:42,787] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1'
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/wkv_1024_bf16/build.ninja...
# Building extension module wkv_1024_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_1024_bf16...
# ###
# ### Model validation start ###
# ###
# ## Model validation for 5 tokens : 100.0% similarity, with 5 matched token, and 0 token mismatch
# ## Model validation for 10 tokens : 100.0% similarity, with 10 matched token, and 0 token mismatch
# ...

# %%
# Lets download the custom models
# !mkdir -p ../../../model/
# !cd ../../../model/ && wget -nc "https://huggingface.co/picocreator/memory-size-experiment-for-rwkv/resolve/main/TokenShift-B-Tune4.pth"
# Out:
# --2023-07-21 14:55:21--  https://huggingface.co/picocreator/memory-size-experiment-for-rwkv/resolve/main/TokenShift-B-Tune4.pth
# Resolving huggingface.co (huggingface.co)... 13.224.249.43, 13.224.249.10, 13.224.249.44, ...
# Connecting to huggingface.co (huggingface.co)|13.224.249.43|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# Memory benchmarking
# !python3 ./memory_script/eval_model_memory_guided.py "../../../model/TokenShift-B-Tune4.pth" "./logs/TokenShift-B-Tune4.csv"
# Out:
# [2023-07-21 14:59:40,716] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1'
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/wkv_1024_bf16/build.ninja...
# Building extension module wkv_1024_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_1024_bf16...
# ###
# ### Model validation start ###
# ###
# ## Model validation for 5 tokens : 100.0% similarity, with 5 matched token, and 0 token mismatch
# ## Model validation for 10 tokens : 100.0% similarity, with 10 matched token, and 0 token mismatch
# ...

# %% [markdown]
# ## TokenShift-C

# %%
# Lets download the custom models
# !mkdir -p ../../../model/
# !cd ../../../model/ && wget -nc "https://huggingface.co/picocreator/memory-size-experiment-for-rwkv/resolve/main/TokenShift-C-Tune4.pth"
# Out:
# --2023-07-23 12:49:54--  https://huggingface.co/picocreator/memory-size-experiment-for-rwkv/resolve/main/tokenshift-exp_TokenShift-C-Tune4.pth
# Resolving huggingface.co (huggingface.co)... 13.33.33.102, 13.33.33.20, 13.33.33.55, ...
# Connecting to huggingface.co (huggingface.co)|13.33.33.102|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# Memory benchmarking
# !python3 ./memory_script/eval_model_memory_guided.py "../../../model/TokenShift-C-Tune4.pth" "./logs/TokenShift-C-Tune4.csv"
# Out:
# [2023-07-21 14:59:40,716] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1'
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/wkv_1024_bf16/build.ninja...
# Building extension module wkv_1024_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_1024_bf16...
# ###
# ### Model validation start ###
# ###
# ## Model validation for 5 tokens : 100.0% similarity, with 5 matched token, and 0 token mismatch
# ## Model validation for 10 tokens : 100.0% similarity, with 10 matched token, and 0 token mismatch
# ...
